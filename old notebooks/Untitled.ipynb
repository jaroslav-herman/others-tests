# %%
files = [
    r"C:\Users\Herman\Desktop\New folder (3)\L_1_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_2_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_3_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_4_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_5_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_6_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
    r"C:\Users\Herman\Desktop\New folder (3)\L_7_Loopeis 1,52V_CE_30s_2_PEIS 60kHz_03_PEIS.mpt",
]

# %%
import numpy as np
import wepy.basics as we
import matplotlib.pyplot as plt

# %%
for i,file in enumerate(files):
    df = we.read_file(file)
    t = df['time/s']
    plt.plot([i]*len(t),t)
