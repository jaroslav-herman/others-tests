# %%
# Python modules 
import numpy as np
# import matplotlib
import matplotlib.pyplot as plt
# matplotlib.rcParams.update(matplotlib.rcParamsDefault)
import pandas as pd
import importlib
from numpy import loadtxt


import os
from glob import glob

folder = glob(os.path.join(r'C:/Users/Herman/Desktop/WE/testDRT/spectra/'))[0]
files = glob(os.path.join(folder,'*3*'+'.txt'))
print(folder)
data = np.loadtxt(files[0],skiprows = 3)

data_after = np.array([np.flip(data[:,0]),np.flip(data[:,1]),np.flip(data[:,2])])
print(data_after)
np.savetxt(folder+'spectrum3new.txt', data_after.T)
# Out:
# C:/Users/Herman/Desktop/WE/testDRT/spectra/
# [[ 1.00000000e+08  9.46132376e+07  8.95166472e+07 ...  1.11711065e-04
#    1.05693455e-04  1.00000000e-04]
#  [ 5.00000001e+01  5.00000001e+01  5.00000001e+01 ...  1.49999994e+02
#    1.49999994e+02  1.49999995e+02]
#  [-1.59170858e-03 -1.68233180e-03 -1.77811461e-03 ... -1.75492857e-02
#   -1.66039475e-02 -1.57095325e-02]]
